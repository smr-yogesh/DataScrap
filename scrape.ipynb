# %%
import pandas as pd
dfs = pd.read_html('http://nepalstock.com/todaysprice/export')
len(dfs)
df = dfs[0]
df.head()
df.columns 
df.iloc[1]
df = df.drop([0,1])
df
df.to_excel('output.xlsx')
# Out:
#                                       Traded Companies  No. Of Transactions  \
# 0              10.35% Agricultural Bank Debenture 2083                    5
# 1         12 % Goodwill Finance Limited Debenture 2083                    3
# 2                           8.5% Sanima Debenture 2087                    1
# 3       9.5% Manjushree Finance Limited Debenture 2085                    1
# 4                              9.5% NCC Debenture 2086                    1
# ..                                                 ...                  ...
# 219                        UNIVERSAL POWER COMPANY LTD                 1000
# 220  Unnati Sahakarya Laghubitta Bittiya Sanstha Li...                   18
# 221                     Upper Tamakoshi Hydropower Ltd                 2148
# 222             Vijaya laghubitta Bittiya Sanstha Ltd.                   45
# 223      Wean Nepal Laghubitta Bittiya Sanstha Limited                  105
#
# ...
